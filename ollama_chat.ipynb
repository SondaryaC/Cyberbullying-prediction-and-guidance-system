# %%
#%pip install --q unstructured langchain
#%pip install --q "unstructured[all-docs]"

# %%
# %pip install langchain-community
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_community.document_loaders import OnlinePDFLoader

# %%
# local_path = "/Users/sondaryachauhan/Desktop/Cyberbullying Project wpork /cyberbullying007.pdf"

# # Local PDF file uploads
# if local_path:
#   loader = UnstructuredPDFLoader(file_path=local_path)
#   data = loader.load()
# else:
#   print("Upload a PDF file")

# local_path = "/Users/sondaryachauhan/Desktop/Cyberbullying Project work /cyberbullying007.pdf"

# # Local PDF file uploads
# if local_path:
#     loader = UnstructuredPDFLoader(file_path=local_path)
#     try:
#         data = loader.load()
#         print(data[0].page_content)
#     except Exception as e:
        
#         print(f"Error loading PDF file: {e}")
# else:
#     print("Upload a PDF file")

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 6.0 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
import pypdf

# %%
from  pypdf import PdfReader

# %%
def load_pdf(file_path):
    text = ''
    with open(file_path, 'rb') as file:
        reader = PdfReader(file)
        for page in reader.pages:
            text += page.extract_text() or ''
    return text

file_path = 'cyberbullying007.pdf'
data = load_pdf(file_path)

print(data)
# Out:
# Preventing Bullying and Cyberbullying | Guidelines for Schools 02I would like to acknowledge the grave issue of bullying and its detrimental effects on individuals.
# Bullying encompasses repeated acts of aggression, including verbal, physical, and social
# behavior, with the intention to inflict physical, social, or psychological harm. It is important to
# recognize that bullying can occur both in person and online, utilizing various digital platforms and
# devices.
# The National Commission for Protection of Child Rights (NCPCR) has been actively working to
# ensure the safety of children in both physical and digital environments. In line with this objective,
# the Commission is pleased to present the "Preventing Bullying and Cyberbullying: Guidelines to
# Schools." These guidelines aim to serve as a comprehensive resource for schools, enabling them
# to prevent, prohibit, and address incidents of bullying that occur within their premises or online
# spaces frequented by children.
# ...

# %%
# !ollama pull nomic-embed-text
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa... 100% ▕████████████████▏  420 B
# verifying sha256 digest
# writing manifest
# removing any unused layers
# success

# %%
#%pip install --q chromadb
#%pip install --q langchain-text-splitters
#!pip install ollama

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.schema import Document

# %%
documents = [Document(page_content=data)]
text_splitter = RecursiveCharacterTextSplitter(chunk_size=7500, chunk_overlap=100)

chunks = text_splitter.split_documents(documents)

for chunk in chunks:
    print(chunk.page_content)
# Out:
# Preventing Bullying and Cyberbullying | Guidelines for Schools 02I would like to acknowledge the grave issue of bullying and its detrimental effects on individuals.
# Bullying encompasses repeated acts of aggression, including verbal, physical, and social
# behavior, with the intention to inflict physical, social, or psychological harm. It is important to
# recognize that bullying can occur both in person and online, utilizing various digital platforms and
# devices.
# The National Commission for Protection of Child Rights (NCPCR) has been actively working to
# ensure the safety of children in both physical and digital environments. In line with this objective,
# the Commission is pleased to present the "Preventing Bullying and Cyberbullying: Guidelines to
# Schools." These guidelines aim to serve as a comprehensive resource for schools, enabling them
# to prevent, prohibit, and address incidents of bullying that occur within their premises or online
# spaces frequented by children.
# ...

# %%
ollama_embed = OllamaEmbeddings(model="nomic-embed-text")

# %%
#vector_db = Chroma.from_documents(
#    documents=chunks, 
#    embedding=OllamaEmbeddings(model="nomic-embed-text",show_progress=True),
#    persist_directory = "./chroma_dbnomic"
#    
#)

# %%
# %pip install chromadb
# Out:
# ...
#   Using cached chromadb-0.5.4-py3-none-any.whl.metadata (6.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.7 MB/s eta 0:00:00
# ...
#   Using cached setuptools-71.0.3-py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached chromadb-0.5.4-py3-none-any.whl (581 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.5/185.5 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 26.2 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.1 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OllamaEmbeddings

# %%
# %pip install chromadb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb

# %%
vector_db = Chroma.from_documents(
    documents=chunks,
    embedding=OllamaEmbeddings(model="nomic-embed-text", show_progress=True),
    persist_directory="./chroma_db_cyber"
)
# Out:
# OllamaEmbeddings: 100%|██████████| 9/9 [00:09<00:00,  1.01s/it]

# %%
vectorstore_disk = Chroma(
                        persist_directory="./chroma_db_cyber",       # Directory of db
                        embedding_function=ollama_embed  # Embedding model
                   )

# %%
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.chat_models import ChatOllama
from langchain_core.runnables import RunnablePassthrough
from langchain.retrievers.multi_query import MultiQueryRetriever

# %%
# LLM from Ollama
local_model = "mistral:7b"
llm = ChatOllama(model=local_model)

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI
# import os

# GOOGLE_API_KEY = "AIzaSyCB0FsriiPfyTLwZGM9z_cDLdl03MFjeFQ"  
# os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# llm = ChatGoogleGenerativeAI(model="gemini-pro",
#                  temperature=0.7, top_p=0.9, top_k=50, convert_system_message_to_human=True
#                               )

# %%
#  QUERY_PROMPT = PromptTemplate(
#      input_variables=["question"],
#      template="""You are an assistant for identifying types of cyberbullying in user tweets and providing prevention strategies based on these identifications. Given a user tweet, your task is to generate five different versions of the tweet to retrieve relevant documents from a vector database. By generating multiple perspectives on the user tweet, your goal is to help overcome some of the limitations of the distance-based similarity search. Provide these alternative versions separated by newlines.
#      If the retrieved context provides information about the prevention of the identified type of cyberbullying, include that in your answer. If the information is not provided in the documents, just say that it is not provided in the documents.
#      Original question: {question}""",
# )
QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""You are an assistant for identifying types of cyberbullying in user tweets and providing prevention strategies based on these identifications. Your task is to detect the type of cyberbullying in the input tweet, categorizing it based on religion, gender, age, ethnicity, or other forms of cyberbullying. If the input tweet is not cyberbullying, specify that it is not cyberbullying. Additionally, provide prevention strategies and advice on how to deal with the identified type of cyberbullying according to the data provided.

Given a user tweet, generate five different versions of the tweet to retrieve relevant documents from a vector database. These alternative versions should help overcome some limitations of distance-based similarity search. Provide these alternative versions separated by newlines.

Original question: {question}"""
)

# %%
# QUERY_PROMPT = PromptTemplate(
#     input_variables=["question"],
#     template=""" You are a helpful and informative bot that answers questions using text from the reference passage included below. \
#     Answer every questions in max 3 lines or in points as required. \
#     Be sure to respond in a complete sentence, being comprehensive, including all relevant background information. \
#     However, you are talking to a non-technical audience, so be sure to break down complicated concepts and \
#     strike a friendly and converstional tone. \
#     If the passage is out of the context from the documents and also out of the law domain, do not answer it. \
#     Try not to include phrases like"Based on the context provided" or "In the context provided" instead use "according to my knowledge" or "As per Advoice Consultancy " or "as far as I know" give answer in a  more genrative and smart manner like a bot AI agent does. \
#     If the passage is out of the context from the documents say that sorry but i am not allowed to answer outside law domain in a respectful manner. \
#     Original question: {question}""",
# )

# %%
retriever = MultiQueryRetriever.from_llm(
    vectorstore_disk.as_retriever(), 
    llm,
    prompt=QUERY_PROMPT
)

# RAG prompt
template = """Answer the question based ONLY on the following context:
{context}
Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
#result = chain.invoke(input("I am a high school student, my seniors bully me alot because I once i talked back at him, what should i do in this situation?"))
